# %% [markdown]
# # Train & Save the Model

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy

# Create the MountainCar environment
env = gym.make("MountainCar-v0")

# Create the PPO agent
model = PPO("MlpPolicy", env, verbose=1)

# Train the agent
model.learn(total_timesteps=10000000)

# Evaluate the agent
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10, render=False)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")

# Save the trained model
model.save("ppo_mountaincar")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 2490     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1456         |
# |    iterations           | 2            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0044694524 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -0.000796    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.6         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000994    |
# |    value_loss           | 135          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1263        |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009660622 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.034      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 86.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1205        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009030551 |
# |    clip_fraction        | 0.00937     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00791    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.1        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00317    |
# |    value_loss           | 83.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1149        |
# |    iterations           | 5           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.004411361 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.0072      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 68.4        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | -200          |
# | time/                   |               |
# |    fps                  | 1122          |
# |    iterations           | 6             |
# |    time_elapsed         | 10            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00013922778 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.09         |
# |    explained_variance   | -0.00314      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.97          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | 0.000125      |
# |    value_loss           | 53.8          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1123        |
# |    iterations           | 7           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009264528 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -5.53e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.11        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 41          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1115        |
# |    iterations           | 8           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.005488897 |
# |    clip_fraction        | 0.0143      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00299     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.49        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00141    |
# |    value_loss           | 30          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1109        |
# |    iterations           | 9           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.005847092 |
# |    clip_fraction        | 0.0118      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00192     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00253    |
# |    value_loss           | 20.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1107         |
# |    iterations           | 10           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0073646875 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.00231     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.754        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00167     |
# |    value_loss           | 13.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1100        |
# |    iterations           | 11          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013848357 |
# |    clip_fraction        | 0.0104      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.000163   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.37        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00106     |
# |    value_loss           | 9.25        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 200        |
# |    ep_rew_mean          | -200       |
# | time/                   |            |
# |    fps                  | 1098       |
# |    iterations           | 12         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.00561215 |
# |    clip_fraction        | 0.000732   |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.09      |
# |    explained_variance   | -0.00116   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.279      |
# |    n_updates            | 110        |
# |    policy_gradient_loss | 3.77e-06   |
# |    value_loss           | 5.68       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1090        |
# |    iterations           | 13          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009750148 |
# |    clip_fraction        | 0.00771     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00094    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.152       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 3.54        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 14          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011222567 |
# |    clip_fraction        | 0.0419      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00162    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.245       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 2.23        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 15           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0091139525 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000681    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.121        |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1084         |
# |    iterations           | 16           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0010832394 |
# |    clip_fraction        | 0.00757      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00177     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.108        |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000111    |
# |    value_loss           | 0.9          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 17           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0026781647 |
# |    clip_fraction        | 0.00127      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000526     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0665       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -7.14e-05    |
# |    value_loss           | 0.568        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1082         |
# |    iterations           | 18           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0043807547 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.000269    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0457       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.000364    |
# |    value_loss           | 0.374        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 19          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009422124 |
# |    clip_fraction        | 0.00176     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.00102    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0511      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00143    |
# |    value_loss           | 0.229       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1078        |
# |    iterations           | 20          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008354987 |
# |    clip_fraction        | 0.00703     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | -0.000526   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0364      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.000685   |
# |    value_loss           | 0.141       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | -200         |
# | time/                   |              |
# |    fps                  | 1075         |
# |    iterations           | 21           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0061310576 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00111      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0153       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0015      |
# |    value_loss           | 0.0949       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | -200        |
# | time/                   |             |
# |    fps                  | 1075        |
# |    iterations           | 22          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007729949 |
# |    clip_fraction        | 0.0249      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 2.24e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00483     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 0.0654      |
# -----------------------------------------

# %% [markdown]
# # Test The Model

# %%
# Test the trained agent
env = gym.make("MountainCar-v0", render_mode="human")
obs, info = env.reset()
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    if done or truncated:
        obs, info = env.reset()

env.close()
